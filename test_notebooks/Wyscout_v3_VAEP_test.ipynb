# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings(action="ignore", message="credentials were not supplied. open data access only")

# %%
from socceraction.spadl.wyscout import *
from socceraction.data.wyscout import WyscoutLoader
from socceraction.data.base import _localloadjson
from socceraction.data.wyscout.loader import _convert_events
from socceraction.data.wyscout.schema import WyscoutEventSchema

# %% [markdown]
# **Import Version 2 data sample** <br>
# This will be used to compare with the updated v3 results

# %%
v2_obj = _localloadjson("../Data/Events/v2_response.json")
v2_raw_df = pd.DataFrame(v2_obj['events'])
df_events_v2 = _convert_events(pd.DataFrame(v2_raw_df))
events_df_v2 = cast(DataFrame[WyscoutEventSchema], df_events_v2)
events_df_v2.head()
# Out:
#      event_id  game_id  period_id  milliseconds  team_id  player_id  type_id  \
# 0  1646549577  5345057          1        3187.0     3161     372255        8
# 1  1646549578  5345057          1        6645.0     3161      20635        8
# 2  1646549581  5345057          1        9512.0     3161     330003        1
# 3  1646549855  5345057          1        9512.0     3157     344132        1
# 4  1646549582  5345057          1       11790.0     3161          0        5
#
#       type_name  subtype_id           subtype_name  \
# 0          Pass          85            Simple pass
# 1          Pass          83              High pass
# 2          Duel          10               Air duel
# 3          Duel          10               Air duel
# 4  Interruption          50  Ball out of the field
#
#                                    positions                         tags
# 0   [{'x': 49, 'y': 50}, {'x': 34, 'y': 50}]               [{'id': 1801}]
# ...
